# %%
# Test Imports
from CybORG import CybORG    
import inspect    
    
from CybORG.Agents.SimpleAgents.KeyboardAgent import KeyboardAgent    
from CybORG.Agents.Wrappers.TrueStateWrapper import TrueStateWrapper

# %%
if __name__ == "__main__":    
    print("Setup")    
    path = str(inspect.getfile(CybORG))    
    path = path[:-10] + '/Shared/Scenarios/Scenario1b.yaml'    
    
    cyborg = TrueStateWrapper(env=CybORG(path, 'sim'), output_mode='table')    
    agent_name = 'Red'    
    
    results = cyborg.reset(agent=agent_name)    
    observation = results.observation    
    action_space = results.action_space    
    
    agent = KeyboardAgent()    
    
    reward = 0    
    done = False    
    while True:    
        action = agent.get_action(observation, action_space)    
        results = cyborg.step(agent=agent_name, action=action)    
    
        reward += results.reward    
        observation = results.observation    
        if done:    
            print(f"Game Over. Total reward: {reward}")    
            break
# Out:
# Setup
# {'Defender': {'Interface': [{'IP Address': IPv4Address('127.0.0.53')},
#                             {'IP Address': IPv4Address('10.0.11.88')},
#                             {'IP Address': IPv4Address('127.0.0.1'),
#                              'Interface Name': 'lo',
#                              'Subnet': IPv4Network('127.0.0.0/8')},
#                             {'IP Address': IPv4Address('10.0.24.37'),
#                              'Interface Name': 'eth0',
#                              'Subnet': IPv4Network('10.0.24.32/28')}],
#               'Processes': [{'Known Path': <Path.SBIN: 6>,
#                              'Known Process': <ProcessName.INIT: 3>,
#                              'PID': 1,
#                              'PPID': 0,
#                              'Path': '/sbin',
#                              'Process Name': 'init',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 2,
#                              'PPID': 0,
#                              'Process Name': '[kthreadd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 3,
#                              'PPID': 2,
#                              'Process Name': '[rcu_gp]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 4,
#                              'PPID': 2,
#                              'Process Name': '[rcu_par_gp]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 5,
#                              'PPID': 2,
#                              'Process Name': '[kworker/0:0-eve]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 6,
#                              'PPID': 2,
#                              'Process Name': '[kworker/0:0H-kb]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 7,
#                              'PPID': 2,
#                              'Process Name': '[kworker/0:1-rcu]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 8,
#                              'PPID': 2,
#                              'Process Name': '[kworker/u30:0-e]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 9,
#                              'PPID': 2,
#                              'Process Name': '[mm_percpu_wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 10,
#                              'PPID': 2,
#                              'Process Name': '[ksoftirqd/0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 11,
#                              'PPID': 2,
#                              'Process Name': '[rcu_sched]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 12,
#                              'PPID': 2,
#                              'Process Name': '[migration/0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 13,
#                              'PPID': 2,
#                              'Process Name': '[cpuhp/0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 14,
#                              'PPID': 2,
#                              'Process Name': '[kdevtmpfs]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 15,
#                              'PPID': 2,
#                              'Process Name': '[netns]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 16,
#                              'PPID': 2,
#                              'Process Name': '[rcu_tasks_kthre]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 17,
#                              'PPID': 2,
#                              'Process Name': '[kauditd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 18,
#                              'PPID': 2,
#                              'Process Name': '[xenbus]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 19,
#                              'PPID': 2,
#                              'Process Name': '[xenwatch]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 20,
#                              'PPID': 2,
#                              'Process Name': '[khungtaskd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 21,
#                              'PPID': 2,
#                              'Process Name': '[oom_reaper]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 22,
#                              'PPID': 2,
#                              'Process Name': '[writeback]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 23,
#                              'PPID': 2,
#                              'Process Name': '[kcompactd0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 24,
#                              'PPID': 2,
#                              'Process Name': '[ksmd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 25,
#                              'PPID': 2,
#                              'Process Name': '[khugepaged]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 71,
#                              'PPID': 2,
#                              'Process Name': '[kintegrityd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 72,
#                              'PPID': 2,
#                              'Process Name': '[kblockd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 73,
#                              'PPID': 2,
#                              'Process Name': '[blkcg_punt_bio]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 74,
#                              'PPID': 2,
#                              'Process Name': '[tpm_dev_wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 75,
#                              'PPID': 2,
#                              'Process Name': '[ata_sff]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 76,
#                              'PPID': 2,
#                              'Process Name': '[md]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 77,
#                              'PPID': 2,
#                              'Process Name': '[edac-poller]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 78,
#                              'PPID': 2,
#                              'Process Name': '[devfreq_wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 79,
#                              'PPID': 2,
#                              'Process Name': '[watchdogd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 80,
#                              'PPID': 2,
#                              'Process Name': '[kworker/u30:1-e]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 82,
#                              'PPID': 2,
#                              'Process Name': '[kswapd0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 83,
#                              'PPID': 2,
#                              'Process Name': '[ecryptfs-kthrea]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 85,
#                              'PPID': 2,
#                              'Process Name': '[kthrotld]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 86,
#                              'PPID': 2,
#                              'Process Name': '[nvme-wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 87,
#                              'PPID': 2,
#                              'Process Name': '[nvme-reset-wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 88,
#                              'PPID': 2,
#                              'Process Name': '[nvme-delete-wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 89,
#                              'PPID': 2,
#                              'Process Name': '[scsi_eh_0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 90,
#                              'PPID': 2,
#                              'Process Name': '[scsi_tmf_0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 91,
#                              'PPID': 2,
#                              'Process Name': '[scsi_eh_1]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 92,
#                              'PPID': 2,
#                              'Process Name': '[scsi_tmf_1]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 93,
#                              'PPID': 2,
#                              'Process Name': '[kworker/u30:2]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 94,
#                              'PPID': 2,
#                              'Process Name': '[kworker/0:1H-kb]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 95,
#                              'PPID': 2,
#                              'Process Name': '[ipv6_addrconf]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 104,
#                              'PPID': 2,
#                              'Process Name': '[kstrp]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 107,
#                              'PPID': 2,
#                              'Process Name': '[kworker/u31:0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 177,
#                              'PPID': 2,
#                              'Process Name': '[cryptd]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 268,
#                              'PPID': 2,
#                              'Process Name': '[raid5wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 316,
#                              'PPID': 2,
#                              'Process Name': '[jbd2/xvda1-8]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 317,
#                              'PPID': 2,
#                              'Process Name': '[ext4-rsv-conver]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 389,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-journald',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 393,
#                              'PPID': 2,
#                              'Process Name': '[kworker/0:2-cgr]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 398,
#                              'PPID': 2,
#                              'Process Name': '[iscsi_eh]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 401,
#                              'PPID': 2,
#                              'Process Name': '[ib-comp-wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 402,
#                              'PPID': 2,
#                              'Process Name': '[ib-comp-unb-wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 403,
#                              'PPID': 2,
#                              'Process Name': '[ib_mcast]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 404,
#                              'PPID': 2,
#                              'Process Name': '[ib_nl_sa_wq]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 407,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-udevd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 408,
#                              'PPID': 2,
#                              'Process Name': '[rdma_cm]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.SBIN: 6>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 409,
#                              'PPID': 1,
#                              'Path': '/sbin',
#                              'Process Name': 'lvmetad',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 434,
#                              'PPID': 2,
#                              'Process Name': '[loop0]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 437,
#                              'PPID': 2,
#                              'Process Name': '[loop1]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 439,
#                              'PPID': 2,
#                              'Process Name': '[loop2]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 440,
#                              'PPID': 2,
#                              'Process Name': '[loop3]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 560,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-timesyncd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 790,
#                              'PPID': 1,
#                              'Path': '/usr/lib/accountsservice',
#                              'Process Name': 'accounts-daemon',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 798,
#                              'PPID': 1,
#                              'Path': '/snap/amazon-ssm-agent/2012',
#                              'Process Name': 'amazon-ssm-agent',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_SBIN: 8>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 802,
#                              'PPID': 1,
#                              'Path': '/usr/sbin',
#                              'Process Name': 'atd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.BIN: 7>,
#                              'Known Process': <ProcessName.SHELL: 19>,
#                              'PID': 803,
#                              'PPID': 1,
#                              'Path': '/bin',
#                              'Process Name': 'bash',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_SBIN: 8>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 807,
#                              'PPID': 1,
#                              'Path': '/usr/sbin',
#                              'Process Name': 'rsyslogd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_SBIN: 8>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 824,
#                              'PPID': 1,
#                              'Path': '/usr/sbin',
#                              'Process Name': 'acpid',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 825,
#                              'PPID': 1,
#                              'Path': '/usr/lib/snapd',
#                              'Process Name': 'snapd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_BIN: 9>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 827,
#                              'PPID': 1,
#                              'Path': '/usr/bin',
#                              'Process Name': 'dbus-daemon',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 832,
#                              'PPID': 803,
#                              'Path': '/usr/local/bin',
#                              'Process Name': 'velociraptor.bin',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_SBIN: 8>,
#                              'Known Process': <ProcessName.CRON: 4>,
#                              'PID': 844,
#                              'PPID': 1,
#                              'Path': '/usr/sbin',
#                              'Process Name': 'cron',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 847,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-logind',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_BIN: 9>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 852,
#                              'PPID': 1,
#                              'Path': '/usr/bin',
#                              'Process Name': 'python3',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_BIN: 9>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 853,
#                              'PPID': 1,
#                              'Path': '/usr/bin',
#                              'Process Name': 'lxcfs',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 863,
#                              'PPID': 1,
#                              'Path': '/usr/lib/policykit-1',
#                              'Process Name': 'polkitd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_BIN: 9>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 867,
#                              'PPID': 1,
#                              'Path': '/usr/bin',
#                              'Process Name': 'python3',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.SBIN: 6>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 875,
#                              'PPID': 1,
#                              'Path': '/sbin',
#                              'Process Name': 'agetty',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 880,
#                              'PPID': 2,
#                              'Process Name': '[kworker/0:3-cgr]',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.SBIN: 6>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 884,
#                              'PPID': 1,
#                              'Path': '/sbin',
#                              'Process Name': 'agetty',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.USR_BIN: 9>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 1370,
#                              'PPID': 1,
#                              'Path': '/usr/bin',
#                              'Process Name': 'python3',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 1432,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-hostnamed',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 2288,
#                              'PPID': 879,
#                              'Process Name': 'sshd:',
#                              'Process Type': <ProcessType.UNKNOWN: 1>},
#                             {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                               'local_port': 22,
#                                               'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                              'Known Path': <Path.USR_SBIN: 8>,
#                              'Known Process': <ProcessName.SSHD: 7>,
#                              'PID': 879,
#                              'PPID': 1,
#                              'Path': '/usr/sbin',
#                              'Process Name': 'sshd',
#                              'Process Type': <ProcessType.SSH: 2>,
#                              'Username': 'root'},
#                             {'Connections': [{'local_address': IPv4Address('127.0.0.53'),
#                                               'local_port': 53,
#                                               'Transport Protocol': <TransportProtocol.TCP: 2>},
#                                              {'local_address': IPv4Address('127.0.0.53'),
#                                               'local_port': 53,
#                                               'Transport Protocol': <TransportProtocol.UDP: 3>}],
#                              'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 656,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-resolved',
#                              'Process Type': <ProcessType.UNKNOWN: 1>,
#                              'Username': 'systemd+'},
#                             {'Connections': [{'local_address': IPv4Address('10.0.11.88'),
#                                               'local_port': 68,
#                                               'Transport Protocol': <TransportProtocol.UDP: 3>}],
#                              'Known Path': <Path.UNKNOWN: 1>,
#                              'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 634,
#                              'PPID': 1,
#                              'Path': '/lib/systemd',
#                              'Process Name': 'systemd-networkd',
#                              'Process Type': <ProcessType.UNKNOWN: 1>,
#                              'Username': 'systemd+'},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 17653,
#                              'Process Name': 'VelociraptorServer',
#                              'Process Type': <ProcessType.UNKNOWN: 1>,
#                              'Username': 'ubuntu'},
#                             {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                              'PID': 16822,
#                              'Process Name': 'VelociraptorClient',
#                              'Process Type': <ProcessType.UNKNOWN: 1>,
#                              'Username': 'ubuntu'}],
#               'Sessions': [{'Agent': 'Blue',
#                             'ID': 0,
#                             'PID': 17653,
#                             'Timeout': 0,
#                             'Type': <SessionType.VELOCIRAPTOR_SERVER: 8>,
#                             'Username': 'ubuntu'},
#                            {'Agent': 'Blue',
#                             'ID': 9,
#                             'PID': 16822,
#                             'Timeout': 0,
#                             'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                             'Username': 'ubuntu'}],
#               'System info': {'Architecture': <Architecture.x64: 2>,
#                               'Hostname': 'Defender',
#                               'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                               'OSType': <OperatingSystemType.LINUX: 3>,
#                               'OSVersion': <OperatingSystemVersion.U18_04_3: 6>},
#               'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                             {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'}]},
#  'Enterprise0': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                                 'Interface Name': 'lo',
#                                 'Subnet': IPv4Network('127.0.0.0/8')},
#                                {'IP Address': IPv4Address('10.0.24.35'),
#                                 'Interface Name': 'eth0',
#                                 'Subnet': IPv4Network('10.0.24.32/28')}],
#                  'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 22,
#                                                  'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                                 'Known Path': <Path.USR_SBIN: 8>,
#                                 'Known Process': <ProcessName.SSHD: 7>,
#                                 'PID': 1091,
#                                 'PPID': 1,
#                                 'Path': '/usr/sbin',
#                                 'Process Name': 'sshd',
#                                 'Process Type': <ProcessType.SSH: 2>,
#                                 'Username': 'root'},
#                                {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                                 'PID': 18526,
#                                 'Process Name': 'VelociraptorClient',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>,
#                                 'Username': 'ubuntu'}],
#                  'Sessions': [{'Agent': 'Blue',
#                                'ID': 6,
#                                'PID': 18526,
#                                'Timeout': 0,
#                                'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                                'Username': 'ubuntu'}],
#                  'System info': {'Architecture': <Architecture.x64: 2>,
#                                  'Hostname': 'Enterprise0',
#                                  'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                                  'OSType': <OperatingSystemType.LINUX: 3>,
#                                  'OSVersion': <OperatingSystemVersion.U18_04_3: 6>},
#                  'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                                {'Groups': [{'GID': 33}],
#                                 'Username': 'www-data'},
#                                {'Groups': [{'GID': 1001}],
#                                 'Password': 'raspberry',
#                                 'Username': 'pi'},
#                                {'Groups': [{'GID': 1000}],
#                                 'Username': 'ubuntu'},
#                                {'Groups': [{'GID': 1001}],
#                                 'Username': 'GreenAgent'}]},
#  'Enterprise1': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                                 'Interface Name': 'lo',
#                                 'Subnet': IPv4Network('127.0.0.0/8')},
#                                {'IP Address': IPv4Address('10.0.24.39'),
#                                 'Interface Name': 'eth0',
#                                 'Subnet': IPv4Network('10.0.24.32/28')}],
#                  'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 22,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Path': <Path.UNKNOWN: 1>,
#                                 'Known Process': <ProcessName.SSHD: 7>,
#                                 'PID': 3368,
#                                 'PPID': 5956,
#                                 'Path': 'C:\\Program Files\\OpenSSH\\usr\\sbin',
#                                 'Process Name': 'sshd.exe',
#                                 'Process Type': <ProcessType.SSH: 2>,
#                                 'Username': 'sshd_server'},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 135,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.SVCHOST: 2>,
#                                 'PID': 832,
#                                 'Process Name': 'svchost.exe',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 3389,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.SVCHOST: 2>,
#                                 'PID': 4400,
#                                 'Process Name': 'svchost.exe',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 445,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>},
#                                                 {'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 139,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.SMSS: 15>,
#                                 'PID': 4,
#                                 'PPID': 372,
#                                 'Process Name': 'smss.exe',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>,
#                                 'Username': 'SYSTEM'},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 80,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>},
#                                                 {'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 443,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.UNKNOWN: 1>,
#                                 'PID': 3404,
#                                 'Process Name': 'tomcat8.exe',
#                                 'Process Type': <ProcessType.WEBSERVER: 5>,
#                                 'Username': 'NetworkService'},
#                                {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                                 'PID': 27661,
#                                 'Process Name': 'VelociraptorClient',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>,
#                                 'Username': 'SYSTEM'}],
#                  'Sessions': [{'Agent': 'Blue',
#                                'ID': 7,
#                                'PID': 27661,
#                                'Timeout': 0,
#                                'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                                'Username': 'SYSTEM'}],
#                  'System info': {'Architecture': <Architecture.x64: 2>,
#                                  'Hostname': 'Enterprise1',
#                                  'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                                  'OSType': <OperatingSystemType.WINDOWS: 2>,
#                                  'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>},
#                  'User Info': [{'Groups': [{'GID': 0}],
#                                 'Username': 'Administrator'},
#                                {'Username': 'GreenAgent'},
#                                {'Groups': [{'GID': 0}],
#                                 'Password': 'vagrant',
#                                 'Username': 'vagrant'},
#                                {'Username': 'SYSTEM'}]},
#  'Enterprise2': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                                 'Interface Name': 'lo',
#                                 'Subnet': IPv4Network('127.0.0.0/8')},
#                                {'IP Address': IPv4Address('10.0.24.41'),
#                                 'Interface Name': 'eth0',
#                                 'Subnet': IPv4Network('10.0.24.32/28')}],
#                  'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 22,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Path': <Path.UNKNOWN: 1>,
#                                 'Known Process': <ProcessName.SSHD: 7>,
#                                 'PID': 3368,
#                                 'PPID': 5956,
#                                 'Path': 'C:\\Program Files\\OpenSSH\\usr\\sbin',
#                                 'Process Name': 'sshd.exe',
#                                 'Process Type': <ProcessType.SSH: 2>,
#                                 'Username': 'sshd_server'},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 135,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.SVCHOST: 2>,
#                                 'PID': 832,
#                                 'Process Name': 'svchost.exe',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 3389,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.SVCHOST: 2>,
#                                 'PID': 4400,
#                                 'Process Name': 'svchost.exe',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 445,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>},
#                                                 {'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 139,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.SMSS: 15>,
#                                 'PID': 4,
#                                 'PPID': 372,
#                                 'Process Name': 'smss.exe',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>,
#                                 'Username': 'SYSTEM'},
#                                {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 80,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>},
#                                                 {'local_address': IPv4Address('0.0.0.0'),
#                                                  'local_port': 443,
#                                                  'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                                 'Known Process': <ProcessName.UNKNOWN: 1>,
#                                 'PID': 3404,
#                                 'Process Name': 'tomcat8.exe',
#                                 'Process Type': <ProcessType.WEBSERVER: 5>,
#                                 'Username': 'NetworkService'},
#                                {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                                 'PID': 28503,
#                                 'Process Name': 'VelociraptorClient',
#                                 'Process Type': <ProcessType.UNKNOWN: 1>,
#                                 'Username': 'SYSTEM'}],
#                  'Sessions': [{'Agent': 'Blue',
#                                'ID': 8,
#                                'PID': 28503,
#                                'Timeout': 0,
#                                'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                                'Username': 'SYSTEM'}],
#                  'System info': {'Architecture': <Architecture.x64: 2>,
#                                  'Hostname': 'Enterprise2',
#                                  'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                                  'OSType': <OperatingSystemType.WINDOWS: 2>,
#                                  'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>},
#                  'User Info': [{'Groups': [{'GID': 0}],
#                                 'Username': 'Administrator'},
#                                {'Username': 'GreenAgent'},
#                                {'Groups': [{'GID': 0}],
#                                 'Password': 'vagrant',
#                                 'Username': 'vagrant'},
#                                {'Username': 'SYSTEM'}]},
#  'Op_Host0': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                              'Interface Name': 'lo',
#                              'Subnet': IPv4Network('127.0.0.0/8')},
#                             {'IP Address': IPv4Address('10.0.65.250'),
#                              'Interface Name': 'eth0',
#                              'Subnet': IPv4Network('10.0.65.240/28')}],
#               'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                               'local_port': 22,
#                                               'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                              'Known Path': <Path.USR_SBIN: 8>,
#                              'Known Process': <ProcessName.SSHD: 7>,
#                              'PID': 1091,
#                              'PPID': 1,
#                              'Path': '/usr/sbin',
#                              'Process Name': 'sshd',
#                              'Process Type': <ProcessType.SSH: 2>,
#                              'Username': 'root'},
#                             {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                              'PID': 25738,
#                              'Process Name': 'VelociraptorClient',
#                              'Process Type': <ProcessType.UNKNOWN: 1>,
#                              'Username': 'ubuntu'},
#                             {'Known Process': <ProcessName.UNKNOWN: 1>,
#                              'PID': 13536,
#                              'Process Name': 'Session',
#                              'Process Type': <ProcessType.UNKNOWN: 1>,
# ...
#                           'Process Type': <ProcessType.SMB: 4>,
#                           'Username': 'SYSTEM'},
#                          {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                           'PID': 19141,
#                           'Process Name': 'VelociraptorClient',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'ubuntu'},
#                          {'Known Process': <ProcessName.UNKNOWN: 1>,
#                           'PID': 18178,
#                           'Process Name': 'Session',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'GreenAgent'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 2,
#                          'PID': 19141,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'},
#                         {'Agent': 'Green',
#                          'ID': 1,
#                          'PID': 18178,
#                          'Timeout': 0,
#                          'Type': <SessionType.UNKNOWN: 1>,
#                          'Username': 'GreenAgent'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User1',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'Administrator'},
#                          {'Username': 'GreenAgent'},
#                          {'Groups': [{'GID': 0}],
#                           'Password': 'vagrant',
#                           'Username': 'vagrant'},
#                          {'Username': 'SYSTEM'}]},
#  'User2': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                           'Interface Name': 'lo',
#                           'Subnet': IPv4Network('127.0.0.0/8')},
#                          {'IP Address': IPv4Address('10.0.187.155'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.187.144/28')}],
#            'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 22,
#                                            'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                           'Known Path': <Path.UNKNOWN: 1>,
#                           'Known Process': <ProcessName.SSHD: 7>,
#                           'PID': 3368,
#                           'PPID': 5956,
#                           'Path': 'C:\\Program Files\\OpenSSH\\usr\\sbin',
#                           'Process Name': 'sshd.exe',
#                           'Process Type': <ProcessType.SSH: 2>,
#                           'Username': 'sshd_server'},
#                          {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 135,
#                                            'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                           'Known Process': <ProcessName.SVCHOST: 2>,
#                           'PID': 832,
#                           'Process Name': 'svchost.exe',
#                           'Process Type': <ProcessType.UNKNOWN: 1>},
#                          {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 3389,
#                                            'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                           'Known Process': <ProcessName.SVCHOST: 2>,
#                           'PID': 4400,
#                           'Process Name': 'svchost.exe',
#                           'Process Type': <ProcessType.UNKNOWN: 1>},
#                          {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 445,
#                                            'Transport Protocol': <TransportProtocol.UNKNOWN: 1>},
#                                           {'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 139,
#                                            'Transport Protocol': <TransportProtocol.UNKNOWN: 1>}],
#                           'Known Process': <ProcessName.SMSS: 15>,
#                           'PID': 4,
#                           'PPID': 372,
#                           'Process Name': 'smss.exe',
#                           'Process Type': <ProcessType.SMB: 4>,
#                           'Username': 'SYSTEM'},
#                          {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                           'PID': 25380,
#                           'Process Name': 'VelociraptorClient',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'ubuntu'},
#                          {'Known Process': <ProcessName.UNKNOWN: 1>,
#                           'PID': 29899,
#                           'Process Name': 'Session',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'GreenAgent'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 3,
#                          'PID': 25380,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'},
#                         {'Agent': 'Green',
#                          'ID': 2,
#                          'PID': 29899,
#                          'Timeout': 0,
#                          'Type': <SessionType.UNKNOWN: 1>,
#                          'Username': 'GreenAgent'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User2',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'Administrator'},
#                          {'Username': 'GreenAgent'},
#                          {'Groups': [{'GID': 0}],
#                           'Password': 'vagrant',
#                           'Username': 'vagrant'},
#                          {'Username': 'SYSTEM'}]},
#  'User3': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                           'Interface Name': 'lo',
#                           'Subnet': IPv4Network('127.0.0.0/8')},
#                          {'IP Address': IPv4Address('10.0.187.146'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.187.144/28')}],
#            'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 22,
#                                            'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                           'Known Path': <Path.USR_SBIN: 8>,
#                           'Known Process': <ProcessName.SSHD: 7>,
#                           'PID': 1091,
#                           'PPID': 1,
#                           'Path': '/usr/sbin',
#                           'Process Name': 'sshd',
#                           'Process Type': <ProcessType.SSH: 2>,
#                           'Username': 'root'},
#                          {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 80,
#                                            'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                           'Known Path': <Path.USR_SBIN: 8>,
#                           'Known Process': <ProcessName.APACHE2: 11>,
#                           'PID': 1100,
#                           'PPID': 1,
#                           'Path': '/usr/sbin',
#                           'Process Name': 'apache2',
#                           'Process Type': <ProcessType.WEBSERVER: 5>,
#                           'Username': 'www-data'},
#                          {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                           'PID': 32514,
#                           'Process Name': 'VelociraptorClient',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'ubuntu'},
#                          {'Known Process': <ProcessName.UNKNOWN: 1>,
#                           'PID': 7529,
#                           'Process Name': 'Session',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'GreenAgent'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 4,
#                          'PID': 32514,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'},
#                         {'Agent': 'Green',
#                          'ID': 3,
#                          'PID': 7529,
#                          'Timeout': 0,
#                          'Type': <SessionType.UNKNOWN: 1>,
#                          'Username': 'GreenAgent'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User3',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}], 'Username': 'GreenAgent'}]},
#  'User4': {'Interface': [{'IP Address': IPv4Address('127.0.0.1'),
#                           'Interface Name': 'lo',
#                           'Subnet': IPv4Network('127.0.0.0/8')},
#                          {'IP Address': IPv4Address('10.0.187.151'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.187.144/28')}],
#            'Processes': [{'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 22,
#                                            'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                           'Known Path': <Path.USR_SBIN: 8>,
#                           'Known Process': <ProcessName.SSHD: 7>,
#                           'PID': 1091,
#                           'PPID': 1,
#                           'Path': '/usr/sbin',
#                           'Process Name': 'sshd',
#                           'Process Type': <ProcessType.SSH: 2>,
#                           'Username': 'root'},
#                          {'Connections': [{'local_address': IPv4Address('0.0.0.0'),
#                                            'local_port': 80,
#                                            'Transport Protocol': <TransportProtocol.TCP: 2>}],
#                           'Known Path': <Path.USR_SBIN: 8>,
#                           'Known Process': <ProcessName.APACHE2: 11>,
#                           'PID': 1100,
#                           'PPID': 1,
#                           'Path': '/usr/sbin',
#                           'Process Name': 'apache2',
#                           'Process Type': <ProcessType.WEBSERVER: 5>,
#                           'Username': 'www-data'},
#                          {'Known Process': <ProcessName.VELOCLIENT: 24>,
#                           'PID': 3924,
#                           'Process Name': 'VelociraptorClient',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'ubuntu'},
#                          {'Known Process': <ProcessName.UNKNOWN: 1>,
#                           'PID': 11698,
#                           'Process Name': 'Session',
#                           'Process Type': <ProcessType.UNKNOWN: 1>,
#                           'Username': 'GreenAgent'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 5,
#                          'PID': 3924,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'},
#                         {'Agent': 'Green',
#                          'ID': 4,
#                          'PID': 11698,
#                          'Timeout': 0,
#                          'Type': <SessionType.UNKNOWN: 1>,
#                          'Username': 'GreenAgent'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User4',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}], 'Username': 'GreenAgent'}]},
#  'success': <TrinaryEnum.UNKNOWN: 2>}
# > /home/david/ai/Autonomous-Cyber-Ops/CybORG/Agents/Wrappers/TrueStateWrapper.py(28)observation_change()
#      26         pprint.pprint(obs)
#      27         breakpoint()
# ---> 28         self.tracker.append(obs)
#      29
#      30         if self.output_mode == 'table':
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-6-3d6e073cf5eb> in <module>
#       7     agent_name = 'Red'
#       8
# ----> 9     results = cyborg.reset(agent=agent_name)
#      10     observation = results.observation
#      11     action_space = results.action_space
#
# ~/ai/Autonomous-Cyber-Ops/CybORG/Agents/Wrappers/BaseWrapper.py in reset(self, agent)
#      18         result = self.env.reset(agent)
#      19         result.action_space = self.action_space_change(result.action_space)
# ---> 20         result.observation = self.observation_change(result.observation)
#      21         return result
#      22
#
# ~/ai/Autonomous-Cyber-Ops/CybORG/Agents/Wrappers/TrueStateWrapper.py in observation_change(self, observation)
#      26         pprint.pprint(obs)
#      27         breakpoint()
# ---> 28         self.tracker.append(obs)
#      29
#      30         if self.output_mode == 'table':
#
# ~/ai/Autonomous-Cyber-Ops/CybORG/Agents/Wrappers/TrueStateWrapper.py in observation_change(self, observation)
#      26         pprint.pprint(obs)
#      27         breakpoint()
# ---> 28         self.tracker.append(obs)
#      29
#      30         if self.output_mode == 'table':
#
# ~/anaconda3/envs/ai/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/ai/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:
